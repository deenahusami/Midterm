# %%
f=open("numbers.txt", "r")
a=a.replace('\n',',').split(",")
print(a)
# Out:
# ['2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '6', '7', '4', '3', '', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '6', '7', '4', '3', '6', '8', '4', '5', '2', '', '10', '3', '7', '9', '6', '0', '1', '3', '5', '6', '7', '8', '9', '10', '2', '3', '6', '8', '9', '10', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '', '2', '4', '6', '8', '4', '5', '2', '1', '9', '0', '4', '6', '7', '4', '3', '2', '1', '9', '10', '3', '7', '9', '6']

# %%
import collections
f=open("numbers.txt", "r")
counter=collections.Counter(a)
for key, value in counter.items():
    print(key, value)
# Out:
# 2 19
# 4 22
# 6 26
# 8 13
# 5 10
# 1 14
# 9 24
# 0 9
# 7 17
# 3 20
# 10 14
#  4

# %%
import collections
f=open("numbers.txt", "r")
counter=collections.Counter(a)
for key, value in counter.items():
    print(key, value)
import matplotlib.pyplot as plt
import numpy as np

x=(counter.keys())
y=(counter.values())

plt.title("Frequency Bar")
plt.bar(x,y)
plt.show()
plt.title("Frequency Plot")
plt.plot(x,y)
plt.show()
import json
f=open("numbers.json", "w")
# Out:
# 2 19
# 4 22
# 6 26
# 8 13
# 5 10
# 1 14
# 9 24
# 0 9
# 7 17
# 3 20
# 10 14
#  4

# %%
import matplotlib.pyplot as plt
import numpy as np

x=sorted(counter.keys())
y=sorted(counter.values())

plt.subplot(1,3, 2)
plt.hist(x)
plt.title("Histogram Subplot")
# Out:
# Text(0.5, 1.0, 'Histogram Subplot')

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
month=df.groupby(pd.PeriodIndex(df["Order Date"],freq='M'))["Total Charged"].sum()
print(month)
# Out:
# Order Date
# 2017-01     13.38
# 2018-09     41.73
# 2018-10    231.92
# 2018-11     27.68
# 2018-12    690.01
# 2019-01    116.42
# 2019-02     90.50
# 2019-03     56.60
# 2019-04    183.01
# 2019-08    197.58
# 2019-09    281.65
# 2019-10      9.87
# 2019-11     45.46
# 2020-01    194.34
# 2020-02    105.85
# 2020-04     56.99
# 2020-09     15.08
# 2020-10     31.86
# 2020-12     15.19
# 2021-01     45.62
# 2021-03     41.36
# 2021-04     24.34
# 2021-05     13.31
# 2021-06     68.43
# 2021-10     62.49
# 2022-01    101.66
# Freq: M, Name: Total Charged, dtype: float64
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/2035572743.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].mean()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/3927417115.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 27.349801980198034

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].median()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/3654976240.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 15.92

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].max()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/560756392.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 314.5

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].min()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/3595866763.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 4.23

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].std()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/3683073847.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 48.120113154068925

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"].sum()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/462618085.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
# 2762.3300000000004

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()

df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
df.head()
import matplotlib.pyplot as plt
df.plot.bar(x='Order Date', y='Tax Charged', rot=90, figsize=(20,10))
plt.title("Tax Overtime")
import pandas as pd

df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
df.head()
import matplotlib.pyplot as plt
df.plot.bar(x='Order Date', y='Subtotal', rot=90, figsize=(20,10))
plt.title("Subtotal Overtime")
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/1316425133.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/1316425133.py:13: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
# Text(0.5, 1.0, 'Subtotal Overtime')

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
df.head()
df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
df.head()
import matplotlib.pyplot as plt
Total=df["Subtotal"].sum()
Tax=df["Tax Charged"].sum()
cost = {'Subtotal':Total, 'Tax Charged':Tax}
plt.pie(cost.values(), labels=cost.keys())
plt.title("Tax to Subtotal Spending Proportion")
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/401071110.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/401071110.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
# Text(0.5, 1.0, 'Tax to Subtotal Spending Proportion')

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
df.head()
df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)
df.head()
sale=df.groupby(pd.PeriodIndex(df["Order Date"],freq='M'))["Total Charged"].sum()
import matplotlib.pyplot as plt
df.plot(kind='line',x='Order Date',y='Total Charged');
df.plot(kind='line',x='Order Date',y='Subtotal')
plt.title("Multiple Lines Subplot")
plt.show()
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/2210583943.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/2210583943.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Total Charged"]=df["Total Charged"].str.replace('$', '').astype(float)

# %%
import pandas as pd
df = pd.read_csv('deenaamazon.csv')
df=df.fillna(0)
df.head()
df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
df.head()
df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
df.head()
import numpy as np
import matplotlib.pyplot as plt

x=np.array(df["Order Date"])
y=np.array(df["Tax Charged"])
x2=np.array(df["Order Date"])
y2=np.array(df["Subtotal"])

plt.subplot(1,1,1)
plt.plot(x,y,x2,y2)

plt.title("Multiple Lines Subplot")
# Out:
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/1671885969.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Subtotal"]=df["Subtotal"].str.replace('$', '').astype(float)
# /var/folders/nh/264yb37x5c1bhvxqm_420lpw0000gp/T/ipykernel_5668/1671885969.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Tax Charged"]=df["Tax Charged"].str.replace('$', '').astype(float)
# Text(0.5, 1.0, 'Multiple Lines Subplot')
